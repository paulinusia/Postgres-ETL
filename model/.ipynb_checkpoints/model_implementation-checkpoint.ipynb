# %%
import pandas as pd
import re
import string
import numpy as np

from sklearn.model_selection import train_test_split
from string import digits
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from keras.layers import Input, LSTM, Embedding, Dense
from keras.models import Model
import pickle
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'
CUDA_VISIBLE_DEVICES=1
os.environ["CUDA_VISIBLE_DEVICES"]="0,1"

# %%
txt = pd.read_csv('../output_files/master.csv', index_col=False, error_bad_lines=False)
# Out:
# b'Skipping line 3230: expected 2 fields, saw 3\nSkipping line 6890: expected 2 fields, saw 3\nSkipping line 8694: expected 2 fields, saw 3\n'

# %%
type(txt)
txt = txt.applymap(str)
all_comment_words = set()
all_reply_words = set()
length_list_comment = []
length_list_reply = []
txt.shape
# Out:
# (12063, 2)

# %%
#lower
txt.reply = txt.reply.apply(lambda x: x.lower())
txt.comment = txt.comment.apply(lambda x: x.lower())

#quote removal
txt.comment = txt.comment.apply(lambda x: re.sub("''", '', x))
txt.reply = txt.reply.apply(lambda x: re.sub("''", '', x))
#special char
txt.comment = txt.comment.apply(lambda x: re.sub("[|\^&+\-%*/=!>]", '', x))
txt.reply = txt.reply.apply(lambda x: re.sub("[|\^&+\-%*/=!>]", '', x))

#punctuation
txt.comment = txt.comment.apply(lambda x: re.sub(r'[^\w\s]', "", x))
txt.reply = txt.reply.apply(lambda x: re.sub(r'[^\w\s]', "", x))

#numbers
txt.comment = txt.comment.apply(lambda x: re.sub("[0-9]", '', x))
txt.reply = txt.reply.apply(lambda x: re.sub("[0-9]", '', x))

#extra spacing
#txt.comment = txt.comment.apply("[/^\s+|\s+$|\s+(?=\s)/g]", "")
#txt.reply = txt.reply.replace("[/^\s+|\s+$|\s+(?=\s)/g]", "")

#Start and end tokens ?

txt.reply = txt.reply.apply(lambda x : 'START_' + x + '_END')

# %%
txt
# Out:
#                                                  comment  \
# 0      self important people are this waygt hi im jos...
# 1      i know it seems weird but  censored is conside...
# 2       censored im a oxy addict i go thru everything...
# 3      oh my word i am so tired of frozen so  censore...
# 4              deleted to appease u censored lordfascist
# ...                                                  ...
# 12058  that party was crazy wolverine was drunk and h...
# 12059  the general accepted rule of thumb in ontario ...
# 12060  my own reflection i have a really stupid looki...
# 12061  i swear the shit people come up with sometimes...
# 12062  i dont know either broccoli is  censored ing d...
#
#                                                    reply
# 0      START_ive never seen a brand new inmate they d...
# 1      START_gtturkey baconnein sir turkey bacon is t...
# 2      START_haha nice i also do the empty room shout...
# 3      START_add a  censored you at the beginning als...
# 4      START_getting into the best law uni in brazil ...
# ...                                                  ...
# 12058  START_also how the  censored would we possibly...
# 12059  START_i think this list represents a certain t...
# 12060  START_its super good at holding flavor its my ...
# 12061  START_listen up dudesjust because you have a b...
# 12062  START_one way or another youre getting  censor...
#
# [12063 rows x 2 columns]

# %%
#create list of unique words for both commetn and reply
for comment in txt.comment:
    for word in comment.split():
        if word not in all_comment_words:
            all_comment_words.add(word)
            
for reply in txt.reply:
    for word in reply.split():
        if word not in all_reply_words:
            all_reply_words.add(word)

# %%
#finds the max comment length
for l in txt.comment:
    length_list_comment.append(len(l.split(' ')))
    
max_length_src = np.max(length_list_comment) 

max_length_src
# Out:
# 2046

# %%
#finds the maximum reply length
for l in txt.reply:
    length_list_reply.append(len(l.split(' ')))
    
max_length_tar = np.max(length_list_reply)
max_length_tar
# Out:
# 1750

# %%
#Sort dictionaries alphabetically
source_words = sorted(list(all_comment_words))
target_words = sorted(list(all_reply_words))

# %% [raw]
# print(source_words)

# %%
# Vocab sizes
#increase num_encoder_token by 1, that is num_encoder_token -. vocab_size + 1. 

num_encoder_tokens = len(all_comment_words)+1
num_decoder_tokens = len(all_reply_words)
num_decoder_tokens += 1 #padding
num_encoder_tokens, num_decoder_tokens
# Out:
# (45084, 36313)

# %%
#WORD TO TOKEN DICTIONARY (each word in dict gets an index)

source_token_index = dict([(word, i+1) for i, word in enumerate(source_words)])
target_token_index = dict([(word, i+1) for i, word in enumerate(target_words)])
source_token_index
# Out:
# {'a': 1,
#  'aa': 2,
#  'aaaaaaaand': 3,
#  'aaaaahhhhhhhhh': 4,
#  'aaaaannnd': 5,
#  'aaaah': 6,
#  'aaah': 7,
#  'aaas': 8,
#  'aampe': 9,
#  'aampm': 10,
#  'aang': 11,
#  'aao': 12,
#  'aap': 13,
#  'aaragorn': 14,
#  'aaron': 15,
#  'aarons': 16,
#  'ab': 17,
#  'ababab': 18,
#  'aback': 19,
#  'abandon': 20,
#  'abandoned': 21,
#  'abandoneda': 22,
#  'abandoning': 23,
#  'abandonment': 24,
#  'abandons': 25,
#  'abate': 26,
#  'abbasid': 27,
#  'abbot': 28,
#  'abbott': 29,
#  'abbreviate': 30,
#  'abbreviations': 31,
#  'abbsover': 32,
#  'abc': 33,
#  'abcd': 34,
#  'abcdefg': 35,
#  'abcess': 36,
#  'abd': 37,
#  'abdicate': 38,
#  'abdomen': 39,
#  'abdomenthe': 40,
#  'abdominal': 41,
#  'abducted': 42,
#  'abductor': 43,
#  'abdul': 44,
#  'abdulhassan': 45,
#  'abel': 46,
#  'abercrombie': 47,
#  'abflat': 48,
#  'abhorrent': 49,
#  'abhorring': 50,
#  'abide': 51,
#  'abides': 52,
#  'abiding': 53,
#  'abilities': 54,
#  'abilitiesdevon': 55,
#  'ability': 56,
#  'ablaze': 57,
#  'able': 58,
#  'ablebodiedness': 59,
#  'ableist': 60,
#  'ables': 61,
#  'ably': 62,
#  'abnormal': 63,
#  'aboard': 64,
#  'abode': 65,
#  'abolishing': 66,
#  'abomination': 67,
#  'aboriginal': 68,
#  'aboriginals': 69,
#  'abort': 70,
#  'aborted': 71,
#  'abortedlets': 72,
#  'abortion': 73,
#  'abortionbut': 74,
#  'abortionista': 75,
#  'abortions': 76,
#  'abortionsi': 77,
#  'abortionso': 78,
#  'abott': 79,
#  'abound': 80,
#  'about': 81,
#  'abouta': 82,
#  'aboutgt': 83,
#  'aboutgtst': 84,
#  'abouthe': 85,
#  'abouthow': 86,
#  'abouti': 87,
#  'aboutits': 88,
#  'aboutslut': 89,
#  'aboutthats': 90,
#  'aboutthe': 91,
#  'aboutyes': 92,
#  'aboutyou': 93,
#  'above': 94,
#  'abovedad': 95,
#  'aboveedit': 96,
#  'abovein': 97,
#  'aboveit': 98,
#  'abracadabra': 99,
#  'abraded': 100,
#  'abraham': 101,
#  'abrahamic': 102,
#  'abrasions': 103,
#  'abrasive': 104,
#  'abridging': 105,
#  'abroad': 106,
#  'abroadlately': 107,
#  'abrupt': 108,
#  'abruptly': 109,
#  'abs': 110,
#  'abscess': 111,
#  'absdid': 112,
#  'absence': 113,
#  'absences': 114,
#  'absent': 115,
#  'absentia': 116,
#  'absently': 117,
#  'absentmindedly': 118,
#  'absinth': 119,
#  'abso': 120,
#  'absocensoredinglutely': 121,
#  'absocensoredinglutelythats': 122,
#  'absolut': 123,
#  'absolute': 124,
#  'absolutely': 125,
#  'absolutethere': 126,
#  'absolution': 127,
#  'absolutly': 128,
#  'absolve': 129,
#  'absorb': 130,
#  'absorbed': 131,
#  'absorbing': 132,
#  'absoul': 133,
#  'abstain': 134,
#  'abstained': 135,
#  'abstaining': 136,
#  'abstinence': 137,
#  'abstinenceonly': 138,
#  'abstract': 139,
#  'abstractly': 140,
#  'absurd': 141,
#  'absurdafter': 142,
#  'absurdif': 143,
#  'absurdity': 144,
#  'absurdly': 145,
#  'abu': 146,
#  'abudaoud': 147,
#  'abuelos': 148,
#  'abugina': 149,
#  'abuiyad': 150,
#  'abulance': 151,
#  'abundance': 152,
#  'abuse': 153,
#  'abused': 154,
#  'abusedits': 155,
#  'abusegti': 156,
#  'abusehe': 157,
#  'abusei': 158,
#  'abuseim': 159,
#  'abuseoutside': 160,
#  'abuser': 161,
#  'abusergt': 162,
#  'abusers': 163,
#  'abusersand': 164,
#  'abuses': 165,
#  'abusesecondlygt': 166,
#  'abusing': 167,
#  'abusive': 168,
#  'abut': 169,
#  'aby': 170,
#  'abysmal': 171,
#  'abysmally': 172,
#  'abyss': 173,
#  'ac': 174,
#  'aca': 175,
#  'academia': 176,
#  'academic': 177,
#  'academically': 178,
#  'academicallywhere': 179,
#  'academics': 180,
#  'academies': 181,
#  'academy': 182,
#  'acapulco': 183,
#  'acccount': 184,
#  'accelerate': 185,
#  'accelerated': 186,
#  'accelerator': 187,
#  'accent': 188,
#  'accented': 189,
#  'accents': 190,
#  'accentsare': 191,
#  'accentuated': 192,
#  'accentyou': 193,
#  'accept': 194,
#  'acceptable': 195,
#  'acceptance': 196,
#  'accepted': 197,
#  'accepting': 198,
#  'accepts': 199,
#  'access': 200,
#  'accessed': 201,
#  'accessibility': 202,
#  'accessible': 203,
#  'accessing': 204,
#  'accessories': 205,
#  'accessorize': 206,
#  'accessory': 207,
#  'accetable': 208,
#  'accident': 209,
#  'accidental': 210,
#  'accidentally': 211,
#  'accidentallycall': 212,
#  'accidently': 213,
#  'accidentoops': 214,
#  'accidents': 215,
#  'acclaim': 216,
#  'acclimate': 217,
#  'accommodate': 218,
#  'accommodateim': 219,
#  'accommodating': 220,
#  'accompanied': 221,
#  'accompanies': 222,
#  'accompany': 223,
#  'accompanying': 224,
#  'accompised': 225,
#  'accomplice': 226,
#  'accomplices': 227,
#  'accomplish': 228,
#  'accomplished': 229,
#  'accomplishing': 230,
#  'accomplishment': 231,
#  'accomplishments': 232,
#  'accord': 233,
#  'accordance': 234,
#  'according': 235,
#  'accordingly': 236,
#  'accordion': 237,
#  'accordionchance': 238,
#  'accosted': 239,
#  'account': 240,
#  'accountability': 241,
#  'accountable': 242,
#  'accountafter': 243,
#  'accountant': 244,
#  'accountants': 245,
#  'accountgt': 246,
#  'accounting': 247,
#  'accounts': 248,
#  'accountshow': 249,
#  'accountthe': 250,
#  'accounttime': 251,
#  'accountwhy': 252,
#  'accoutning': 253,
#  'accredited': 254,
#  'acct': 255,
#  'accu': 256,
#  'accumulated': 257,
#  'accumulating': 258,
#  'accuracy': 259,
#  'accurate': 260,
#  'accurategt': 261,
#  'accurately': 262,
#  'accuratetranslation': 263,
#  'accusation': 264,
#  'accusations': 265,
#  'accusationsi': 266,
#  'accusatory': 267,
#  'accuse': 268,
#  'accused': 269,
#  'accusers': 270,
#  'accuses': 271,
#  'accusing': 272,
#  'accustomed': 273,
#  'accutane': 274,
#  'ace': 275,
#  'aced': 276,
#  'acensoreding': 277,
#  'acensoredingmen': 278,
#  'achairscouches': 279,
#  'ache': 280,
#  'acheivmentpleasure': 281,
#  'aches': 282,
#  'achey': 283,
#  'achieve': 284,
#  'achieveafter': 285,
#  'achieved': 286,
#  'achievement': 287,
#  'achiever': 288,
#  'achievers': 289,
#  'achieving': 290,
#  'achilles': 291,
#  'aching': 292,
#  'achondroplastic': 293,
#  'acid': 294,
#  'acidic': 295,
#  'acidmushrooms': 296,
#  'ackbar': 297,
#  'acknowledge': 298,
#  'acknowledged': 299,
#  'acknowledgedi': 300,
#  'acknowledgement': 301,
#  'acknowledges': 302,
#  'acknowledging': 303,
#  'acknowledgment': 304,
#  'acls': 305,
#  'aclu': 306,
#  'aclui': 307,
#  'acne': 308,
#  'acoma': 309,
#  'acon': 310,
#  'acons': 311,
#  'acording': 312,
#  'acoustic': 313,
#  'acquaintance': 314,
#  'acquaintances': 315,
#  'acquainted': 316,
#  'acquiesce': 317,
#  'acquire': 318,
#  'acquired': 319,
#  'acquiring': 320,
#  'acquisition': 321,
#  'acres': 322,
#  'acrid': 323,
#  'acrimonious': 324,
#  'acrobat': 325,
#  'acrobats': 326,
#  'acronym': 327,
#  'acronyms': 328,
#  'across': 329,
#  'acrossand': 330,
#  'act': 331,
#  'acted': 332,
#  'acti': 333,
#  'actin': 334,
#  'acting': 335,
#  'actingits': 336,
#  'actingscreenwriting': 337,
#  'action': 338,
#  'actiondo': 339,
#  'actioned': 340,
#  'actionhero': 341,
#  'actions': 342,
#  'actionsbut': 343,
#  'actionsi': 344,
#  'actionsin': 345,
#  'actionsinaction': 346,
#  'actionsnext': 347,
#  'actionsthe': 348,
#  'actionwhat': 349,
#  'activate': 350,
#  'activated': 351,
#  'activatedgt': 352,
#  'activates': 353,
#  'activating': 354,
#  'activation': 355,
#  'active': 356,
#  'actively': 357,
#  'activisions': 358,
#  'activism': 359,
#  'activist': 360,
#  'activists': 361,
#  'activities': 362,
#  'activitiesbut': 363,
#  'activitiesgpastandardized': 364,
#  'activity': 365,
#  'activityanyway': 366,
#  'activityby': 367,
#  'activityi': 368,
#  'activityive': 369,
#  'activitythats': 370,
#  'actmany': 371,
#  'actor': 372,
#  'actorrip': 373,
#  'actors': 374,
#  'actorsactresses': 375,
#  'actress': 376,
#  'actresses': 377,
#  'acts': 378,
#  'actsestablished': 379,
#  'actslabel': 380,
#  'actthat': 381,
#  'actual': 382,
#  'actuality': 383,
#  'actually': 384,
#  'actuallymy': 385,
#  'actuallyohyeah': 386,
#  'actuallythere': 387,
#  'actwe': 388,
#  'acuras': 389,
#  'acurazine': 390,
#  'acus': 391,
#  'acute': 392,
#  'acutely': 393,
#  'acv': 394,
#  'ad': 395,
#  'adam': 396,
#  'adamant': 397,
#  'adams': 398,
#  'adapt': 399,
#  'adaptability': 400,
#  'adaptation': 401,
#  'adapted': 402,
#  'adapter': 403,
#  'adapters': 404,
#  'adapting': 405,
#  'adaptive': 406,
#  'adapts': 407,
#  'add': 408,
#  'addadhdits': 409,
#  'added': 410,
#  'adderall': 411,
#  'adderallamptrade': 412,
#  'addict': 413,
#  'addicted': 414,
#  'addictedyou': 415,
#  'addictinggamescom': 416,
#  'addiction': 417,
#  'addictions': 418,
#  'addictive': 419,
#  'addicts': 420,
#  'addictthe': 421,
#  'addied': 422,
#  'adding': 423,
#  'addition': 424,
#  'additional': 425,
#  'additionally': 426,
#  'additionallythen': 427,
#  'additionif': 428,
#  'additions': 429,
#  'addled': 430,
#  'addons': 431,
#  'address': 432,
#  'addressed': 433,
#  'addresses': 434,
#  'addressesthe': 435,
#  'addressing': 436,
#  'adds': 437,
#  'addy': 438,
#  'adept': 439,
#  'adequate': 440,
#  'adequately': 441,
#  'adequatelynote': 442,
#  'adhd': 443,
#  'adhdsorry': 444,
#  'adheres': 445,
#  'adhesionsskin': 446,
#  'adhesive': 447,
#  'aditya': 448,
#  'adjacent': 449,
#  'adjective': 450,
#  'adjectives': 451,
#  'adjudicate': 452,
#  'adjust': 453,
#  'adjustable': 454,
#  'adjusted': 455,
#  'adjusting': 456,
#  'adjustments': 457,
#  'adjusts': 458,
#  'admin': 459,
#  'administer': 460,
#  'administered': 461,
#  'administrated': 462,
#  'administration': 463,
#  'administrationoh': 464,
#  'administrative': 465,
#  'administrator': 466,
#  'administrators': 467,
#  'admins': 468,
#  'admirable': 469,
#  'admirably': 470,
#  'admiral': 471,
#  'admiration': 472,
#  'admirationhere': 473,
#  'admire': 474,
#  'admired': 475,
#  'admirer': 476,
#  'admirers': 477,
#  'admiring': 478,
#  'admission': 479,
#  'admissions': 480,
#  'admit': 481,
#  'admited': 482,
#  'admits': 483,
#  'admittably': 484,
#  'admitted': 485,
#  'admittedly': 486,
#  'admitting': 487,
#  'admonish': 488,
#  'admonished': 489,
#  'admonishing': 490,
#  'admonition': 491,
#  'admonitions': 492,
#  'adobe': 493,
#  'adolescence': 494,
#  'adolescencethe': 495,
#  'adolescent': 496,
#  'adolescents': 497,
#  'adolf': 498,
#  'adolph': 499,
#  'adonis': 500,
#  'adooooolph': 501,
#  'adopt': 502,
#  'adopted': 503,
#  'adopting': 504,
#  'adoption': 505,
#  'adoptions': 506,
#  'adoptive': 507,
#  'adopts': 508,
#  'adorable': 509,
#  'adorably': 510,
#  'adore': 511,
#  'adored': 512,
#  'adores': 513,
#  'adoring': 514,
#  'adorning': 515,
#  'adothe': 516,
#  'adrenaline': 517,
#  'adrenalinefilled': 518,
#  'adrenalinesimon': 519,
#  'adrenalinesorry': 520,
#  'adrock': 521,
#  'ads': 522,
#  'adsupported': 523,
#  'adult': 524,
#  'adultalso': 525,
#  'adultfamily': 526,
#  'adulthood': 527,
#  'adultmy': 528,
#  'adults': 529,
#  'adultsoh': 530,
#  'adultyou': 531,
#  'advance': 532,
#  'advancecarterdathird': 533,
#  'advanced': 534,
#  'advancement': 535,
#  'advancements': 536,
#  'advances': 537,
#  'advantage': 538,
#  'advantageous': 539,
#  'advantages': 540,
#  'advent': 541,
#  'adventure': 542,
#  'adventurer': 543,
#  'adventurerstalking': 544,
#  'adventures': 545,
#  'adventurous': 546,
#  'adverb': 547,
#  'adverbs': 548,
#  'adversaries': 549,
#  'adversarys': 550,
#  'adverse': 551,
#  'advertise': 552,
#  'advertised': 553,
#  'advertisement': 554,
#  'advertisements': 555,
#  'advertisementsnever': 556,
#  'advertisementsnotice': 557,
#  'advertisers': 558,
#  'advertiserso': 559,
#  'advertises': 560,
#  'advertising': 561,
#  'advertisingwell': 562,
#  'adverts': 563,
#  'advice': 564,
#  'adviceameen': 565,
#  'adviceanimal': 566,
#  'adviceanimals': 567,
#  'adviceif': 568,
#  'adviceno': 569,
#  'advicepick': 570,
#  'adviceus': 571,
#  'advicewe': 572,
#  'advisable': 573,
#  'advise': 574,
#  'advised': 575,
#  'adviser': 576,
#  'advises': 577,
#  'advising': 578,
#  'advisor': 579,
#  'advocate': 580,
#  'advocated': 581,
#  'advocates': 582,
#  'advocating': 583,
#  'adware': 584,
#  'adz': 585,
#  'aeilish': 586,
#  'aeilishs': 587,
#  'aeons': 588,
#  'aeop': 589,
#  'aequi': 590,
#  'aerial': 591,
#  'aerobics': 592,
#  'aerogel': 593,
#  'aeronautical': 594,
#  'aeroplane': 595,
#  'aerosol': 596,
#  'aerospace': 597,
#  'aesop': 598,
#  'aesthetic': 599,
#  'aesthetically': 600,
#  'aestheticeither': 601,
#  'aesthetics': 602,
#  'aetna': 603,
#  'af': 604,
#  'afaik': 605,
#  'afar': 606,
#  'aferwords': 607,
#  'aff': 608,
#  'affable': 609,
#  'affair': 610,
#  'affairi': 611,
#  'affairone': 612,
#  'affairs': 613,
#  'affairsgtth': 614,
#  'affect': 615,
#  'affected': 616,
#  'affecting': 617,
#  'affection': 618,
#  'affectionate': 619,
#  'affects': 620,
#  'affectual': 621,
#  'affidavit': 622,
#  'affiliate': 623,
#  'affiliated': 624,
#  'affirmation': 625,
#  'affirmative': 626,
#  'affirmed': 627,
#  'affirming': 628,
#  'affirms': 629,
#  'affleck': 630,
#  'afflicted': 631,
#  'afflictions': 632,
#  'affluent': 633,
#  'affluenza': 634,
#  'afford': 635,
#  'affordable': 636,
#  'afforded': 637,
#  'affordedit': 638,
#  'affording': 639,
#  'affront': 640,
#  'afghan': 641,
#  'afghanistan': 642,
#  'afk': 643,
#  'aflac': 644,
#  'aflame': 645,
#  'afoot': 646,
#  'afore': 647,
#  'aforementioned': 648,
#  'aforethought': 649,
#  'afraid': 650,
#  'afraidarthur': 651,
#  'afreshid': 652,
#  'africa': 653,
#  'africacensored': 654,
#  'africacpp': 655,
#  'african': 656,
#  'africanalien': 657,
#  'africanamericans': 658,
#  'africans': 659,
#  'africathis': 660,
#  'afro': 661,
#  'afroman': 662,
#  'afso': 663,
#  'aftemath': 664,
#  'after': 665,
#  'afterall': 666,
#  'afteram': 667,
#  'afteremily': 668,
#  'aftergthow': 669,
#  'afterhands': 670,
#  'afterhow': 671,
#  'afterlife': 672,
#  'afterlifeis': 673,
#  'aftermarket': 674,
#  'aftermath': 675,
#  'aftermathmy': 676,
#  'aftermy': 677,
#  'afternoon': 678,
#  'afternoonit': 679,
#  'afternoons': 680,
#  'afternow': 681,
#  'afterparty': 682,
#  'afterprom': 683,
#  'afterschool': 684,
#  'aftertaste': 685,
#  'afterthat': 686,
#  'afterthis': 687,
#  'afterward': 688,
#  'afterwards': 689,
#  'afterwardsgt': 690,
#  'afterwardsi': 691,
#  'afterwardsmy': 692,
#  'afterwardsthe': 693,
#  'afterwardsthis': 694,
#  'afterwardswow': 695,
#  'afterwhat': 696,
#  'afterwords': 697,
#  'ag': 698,
#  'aga': 699,
#  'again': 700,
#  'againafter': 701,
#  'againand': 702,
#  'againas': 703,
#  'againbrother': 704,
#  'againby': 705,
#  'againcounselling': 706,
#  'againdid': 707,
#  'againdifficulty': 708,
#  'againdo': 709,
#  'againdont': 710,
#  'againdt': 711,
#  'againedit': 712,
#  'againeditholy': 713,
#  'againfunny': 714,
#  'againgenerally': 715,
#  'againgetting': 716,
#  'againgod': 717,
#  'againgspot': 718,
#  'againgt': 719,
#  'againhere': 720,
#  'againheres': 721,
#  'againi': 722,
#  'againid': 723,
#  'againif': 724,
#  'againim': 725,
#  'againit': 726,
#  'againits': 727,
#  'againlesson': 728,
#  'againloving': 729,
#  'againmakes': 730,
#  'againmaybe': 731,
#  'againmy': 732,
#  'againnot': 733,
#  'againnow': 734,
#  'againoh': 735,
#  'againokay': 736,
#  'againoutbreak': 737,
#  'againput': 738,
#  'againrealistically': 739,
#  'againshe': 740,
#  'againso': 741,
#  'againsorry': 742,
#  'against': 743,
#  'againsteves': 744,
#  'againstrezeas': 745,
#  'againsure': 746,
#  'againtext': 747,
#  'againthe': 748,
#  'againthen': 749,
#  'againtheres': 750,
#  'againthis': 751,
#  'againtldr': 752,
#  'againtotally': 753,
#  'againtyler': 754,
#  'againuh': 755,
#  'againwait': 756,
#  'againwe': 757,
#  'againwhat': 758,
#  'againwhen': 759,
#  'againwith': 760,
#  'againyes': 761,
#  'againyou': 762,
#  'againyour': 763,
#  'againyoure': 764,
#  'agape': 765,
#  'agassi': 766,
#  'age': 767,
#  'ageand': 768,
#  'ageappropriate': 769,
#  'agearthur': 770,
#  'aged': 771,
#  'agegt': 772,
#  'agegti': 773,
#  'agehe': 774,
#  'ageimagine': 775,
#  'ageing': 776,
#  'ageit': 777,
#  'ageless': 778,
#  'agelets': 779,
#  'agemy': 780,
#  'agencies': 781,
#  'agency': 782,
#  'agencytry': 783,
#  'agenda': 784,
#  'agent': 785,
#  'agents': 786,
#  'ages': 787,
#  'agesduring': 788,
#  'agesgtim': 789,
#  'ageshush': 790,
#  'ageso': 791,
#  'agggh': 792,
#  'aggies': 793,
#  'aggrandizing': 794,
#  'aggravate': 795,
#  'aggravation': 796,
#  'aggression': 797,
#  'aggressive': 798,
#  'aggressiveits': 799,
#  'aggressively': 800,
#  'aggressivemore': 801,
#  'aggressiveso': 802,
#  'aggressor': 803,
#  'aggressors': 804,
#  'aggrieved': 805,
#  'aggrivated': 806,
#  'aggro': 807,
#  'aghast': 808,
#  'agile': 809,
#  'agility': 810,
#  'aging': 811,
#  'agitated': 812,
#  'agnostic': 813,
#  'ago': 814,
#  'agoacknowledge': 815,
#  'agoand': 816,
#  'agobbcworld': 817,
#  'agobecause': 818,
#  'agobut': 819,
#  'agocant': 820,
#  'agocasual': 821,
#  'agoedit': 822,
#  'agogti': 823,
#  'agoheres': 824,
#  'agoi': 825,
#  'agoin': 826,
#  'agoits': 827,
#  'agolong': 828,
#  'agomans': 829,
#  'agonized': 830,
#  'agonizing': 831,
#  'agonizingly': 832,
#  'agony': 833,
#  'agonyguys': 834,
#  'agooh': 835,
#  'agoseriously': 836,
#  'agoshes': 837,
#  'agoshit': 838,
#  'agoso': 839,
#  'agosource': 840,
#  'agothere': 841,
#  'agrabahreapedage': 842,
#  'agree': 843,
#  'agreeable': 844,
#  'agreeadmit': 845,
#  'agreed': 846,
#  'agreeing': 847,
#  'agreement': 848,
#  'agreements': 849,
#  'agreementwell': 850,
#  'agreeok': 851,
#  'agrees': 852,
#  'agreethis': 853,
#  'agricultural': 854,
#  'agriculture': 855,
#  'agriculturegt': 856,
#  'agriculturemale': 857,
#  'agronar': 858,
#  'agronomic': 859,
#  'ags': 860,
#  'ah': 861,
#  'ahab': 862,
#  'ahahaha': 863,
#  'ahboohoo': 864,
#  'ahead': 865,
#  'aheadtldr': 866,
#  'ahem': 867,
#  'ahh': 868,
#  'ahhh': 869,
#  'ahhhh': 870,
#  'ahi': 871,
#  'ahmed': 872,
#  'ahmedyeah': 873,
#  'ahmyou': 874,
#  'ahold': 875,
#  'ahole': 876,
#  'aholeabout': 877,
#  'aholealso': 878,
#  'aholecute': 879,
#  'aholeevery': 880,
#  'aholeftfybeing': 881,
#  'aholegt': 882,
#  'aholei': 883,
#  'aholeim': 884,
#  'aholeit': 885,
#  'aholeive': 886,
#  'aholemaybe': 887,
#  'aholemeh': 888,
#  'aholeness': 889,
#  'aholery': 890,
#  'aholethese': 891,
#  'aholewomen': 892,
#  'aholeyou': 893,
#  'ahoy': 894,
#  'ahs': 895,
#  'ahthis': 896,
#  'ahve': 897,
#  'ai': 898,
#  'aid': 899,
#  'aide': 900,
#  'aiden': 901,
#  'aides': 902,
#  'aidits': 903,
#  'aids': 904,
#  'aiguillettes': 905,
#  'aiko': 906,
#  'aim': 907,
#  'aimed': 908,
#  'aiming': 909,
#  'aims': 910,
#  'aimwhat': 911,
#  'aint': 912,
#  'air': 913,
#  'airanyone': 914,
#  'airbender': 915,
#  'airborn': 916,
#  'airborne': 917,
#  'airbrush': 918,
#  'aircard': 919,
#  'aircraft': 920,
#  'airdennis': 921,
#  'aired': 922,
#  'airfield': 923,
#  'airfields': 924,
#  'airhowever': 925,
#  'airing': 926,
#  'airings': 927,
#  'airline': 928,
#  'airlines': 929,
#  'airplane': 930,
#  'airplanesjust': 931,
#  'airplay': 932,
#  'airport': 933,
#  'airportbring': 934,
#  'airports': 935,
#  'airs': 936,
#  'airspace': 937,
#  'airstrikes': 938,
#  'airwalk': 939,
#  'airway': 940,
#  'airwaysyou': 941,
#  'airyfairy': 942,
#  'aisle': 943,
#  'aisledespite': 944,
#  'aisles': 945,
#  'ait': 946,
#  'aitkin': 947,
#  'ajar': 948,
#  'ak': 949,
#  'aka': 950,
#  'akafrank': 951,
#  'akbar': 952,
#  'ake': 953,
#  'akimbo': 954,
#  'akin': 955,
#  'akira': 956,
#  'akkadian': 957,
#  'aknc': 958,
#  'aku': 959,
#  'al': 960,
#  'ala': 961,
#  'alabama': 962,
#  'aladdin': 963,
#  'alamo': 964,
#  'alan': 965,
#  'alanis': 966,
#  'alarm': 967,
#  'alarmed': 968,
#  'alarming': 969,
#  'alarmingly': 970,
#  'alarmist': 971,
#  'alarms': 972,
#  'alas': 973,
#  'alaska': 974,
#  'alaskan': 975,
#  'alays': 976,
#  'albania': 977,
#  'albany': 978,
#  'albatross': 979,
#  'albeit': 980,
#  'albert': 981,
#  'albertan': 982,
#  'alberteinsteinit': 983,
#  'alberts': 984,
#  'albino': 985,
#  'albrecht': 986,
#  'albright': 987,
#  'album': 988,
#  'albuma': 989,
#  'albumchief': 990,
#  'albumdetox': 991,
#  'albumin': 992,
#  'albumnoname': 993,
#  'albums': 994,
#  'albumtde': 995,
#  'albumwhat': 996,
#  'alchemist': 997,
#  'alchemists': 998,
#  'alchol': 999,
#  'alcohol': 1000,
#  ...}

# %%
# Create token to word dictionary for both source and target
#puts index first
reverse_source_char_index = dict((i,word) for word, i in source_token_index.items())
reverse_target_char_index = dict((i,word) for word, i in target_token_index.items())
reverse_source_char_index
# Out:
# {1: 'a',
#  2: 'aa',
#  3: 'aaaaaaaand',
#  4: 'aaaaahhhhhhhhh',
#  5: 'aaaaannnd',
#  6: 'aaaah',
#  7: 'aaah',
#  8: 'aaas',
#  9: 'aampe',
#  10: 'aampm',
#  11: 'aang',
#  12: 'aao',
#  13: 'aap',
#  14: 'aaragorn',
#  15: 'aaron',
#  16: 'aarons',
#  17: 'ab',
#  18: 'ababab',
#  19: 'aback',
#  20: 'abandon',
#  21: 'abandoned',
#  22: 'abandoneda',
#  23: 'abandoning',
#  24: 'abandonment',
#  25: 'abandons',
#  26: 'abate',
#  27: 'abbasid',
#  28: 'abbot',
#  29: 'abbott',
#  30: 'abbreviate',
#  31: 'abbreviations',
#  32: 'abbsover',
#  33: 'abc',
#  34: 'abcd',
#  35: 'abcdefg',
#  36: 'abcess',
#  37: 'abd',
#  38: 'abdicate',
#  39: 'abdomen',
#  40: 'abdomenthe',
#  41: 'abdominal',
#  42: 'abducted',
#  43: 'abductor',
#  44: 'abdul',
#  45: 'abdulhassan',
#  46: 'abel',
#  47: 'abercrombie',
#  48: 'abflat',
#  49: 'abhorrent',
#  50: 'abhorring',
#  51: 'abide',
#  52: 'abides',
#  53: 'abiding',
#  54: 'abilities',
#  55: 'abilitiesdevon',
#  56: 'ability',
#  57: 'ablaze',
#  58: 'able',
#  59: 'ablebodiedness',
#  60: 'ableist',
#  61: 'ables',
#  62: 'ably',
#  63: 'abnormal',
#  64: 'aboard',
#  65: 'abode',
#  66: 'abolishing',
#  67: 'abomination',
#  68: 'aboriginal',
#  69: 'aboriginals',
#  70: 'abort',
#  71: 'aborted',
#  72: 'abortedlets',
#  73: 'abortion',
#  74: 'abortionbut',
#  75: 'abortionista',
#  76: 'abortions',
#  77: 'abortionsi',
#  78: 'abortionso',
#  79: 'abott',
#  80: 'abound',
#  81: 'about',
#  82: 'abouta',
#  83: 'aboutgt',
#  84: 'aboutgtst',
#  85: 'abouthe',
#  86: 'abouthow',
#  87: 'abouti',
#  88: 'aboutits',
#  89: 'aboutslut',
#  90: 'aboutthats',
#  91: 'aboutthe',
#  92: 'aboutyes',
#  93: 'aboutyou',
#  94: 'above',
#  95: 'abovedad',
#  96: 'aboveedit',
#  97: 'abovein',
#  98: 'aboveit',
#  99: 'abracadabra',
#  100: 'abraded',
#  101: 'abraham',
#  102: 'abrahamic',
#  103: 'abrasions',
#  104: 'abrasive',
#  105: 'abridging',
#  106: 'abroad',
#  107: 'abroadlately',
#  108: 'abrupt',
#  109: 'abruptly',
#  110: 'abs',
#  111: 'abscess',
#  112: 'absdid',
#  113: 'absence',
#  114: 'absences',
#  115: 'absent',
#  116: 'absentia',
#  117: 'absently',
#  118: 'absentmindedly',
#  119: 'absinth',
#  120: 'abso',
#  121: 'absocensoredinglutely',
#  122: 'absocensoredinglutelythats',
#  123: 'absolut',
#  124: 'absolute',
#  125: 'absolutely',
#  126: 'absolutethere',
#  127: 'absolution',
#  128: 'absolutly',
#  129: 'absolve',
#  130: 'absorb',
#  131: 'absorbed',
#  132: 'absorbing',
#  133: 'absoul',
#  134: 'abstain',
#  135: 'abstained',
#  136: 'abstaining',
#  137: 'abstinence',
#  138: 'abstinenceonly',
#  139: 'abstract',
#  140: 'abstractly',
#  141: 'absurd',
#  142: 'absurdafter',
#  143: 'absurdif',
#  144: 'absurdity',
#  145: 'absurdly',
#  146: 'abu',
#  147: 'abudaoud',
#  148: 'abuelos',
#  149: 'abugina',
#  150: 'abuiyad',
#  151: 'abulance',
#  152: 'abundance',
#  153: 'abuse',
#  154: 'abused',
#  155: 'abusedits',
#  156: 'abusegti',
#  157: 'abusehe',
#  158: 'abusei',
#  159: 'abuseim',
#  160: 'abuseoutside',
#  161: 'abuser',
#  162: 'abusergt',
#  163: 'abusers',
#  164: 'abusersand',
#  165: 'abuses',
#  166: 'abusesecondlygt',
#  167: 'abusing',
#  168: 'abusive',
#  169: 'abut',
#  170: 'aby',
#  171: 'abysmal',
#  172: 'abysmally',
#  173: 'abyss',
#  174: 'ac',
#  175: 'aca',
#  176: 'academia',
#  177: 'academic',
#  178: 'academically',
#  179: 'academicallywhere',
#  180: 'academics',
#  181: 'academies',
#  182: 'academy',
#  183: 'acapulco',
#  184: 'acccount',
#  185: 'accelerate',
#  186: 'accelerated',
#  187: 'accelerator',
#  188: 'accent',
#  189: 'accented',
#  190: 'accents',
#  191: 'accentsare',
#  192: 'accentuated',
#  193: 'accentyou',
#  194: 'accept',
#  195: 'acceptable',
#  196: 'acceptance',
#  197: 'accepted',
#  198: 'accepting',
#  199: 'accepts',
#  200: 'access',
#  201: 'accessed',
#  202: 'accessibility',
#  203: 'accessible',
#  204: 'accessing',
#  205: 'accessories',
#  206: 'accessorize',
#  207: 'accessory',
#  208: 'accetable',
#  209: 'accident',
#  210: 'accidental',
#  211: 'accidentally',
#  212: 'accidentallycall',
#  213: 'accidently',
#  214: 'accidentoops',
#  215: 'accidents',
#  216: 'acclaim',
#  217: 'acclimate',
#  218: 'accommodate',
#  219: 'accommodateim',
#  220: 'accommodating',
#  221: 'accompanied',
#  222: 'accompanies',
#  223: 'accompany',
#  224: 'accompanying',
#  225: 'accompised',
#  226: 'accomplice',
#  227: 'accomplices',
#  228: 'accomplish',
#  229: 'accomplished',
#  230: 'accomplishing',
#  231: 'accomplishment',
#  232: 'accomplishments',
#  233: 'accord',
#  234: 'accordance',
#  235: 'according',
#  236: 'accordingly',
#  237: 'accordion',
#  238: 'accordionchance',
#  239: 'accosted',
#  240: 'account',
#  241: 'accountability',
#  242: 'accountable',
#  243: 'accountafter',
#  244: 'accountant',
#  245: 'accountants',
#  246: 'accountgt',
#  247: 'accounting',
#  248: 'accounts',
#  249: 'accountshow',
#  250: 'accountthe',
#  251: 'accounttime',
#  252: 'accountwhy',
#  253: 'accoutning',
#  254: 'accredited',
#  255: 'acct',
#  256: 'accu',
#  257: 'accumulated',
#  258: 'accumulating',
#  259: 'accuracy',
#  260: 'accurate',
#  261: 'accurategt',
#  262: 'accurately',
#  263: 'accuratetranslation',
#  264: 'accusation',
#  265: 'accusations',
#  266: 'accusationsi',
#  267: 'accusatory',
#  268: 'accuse',
#  269: 'accused',
#  270: 'accusers',
#  271: 'accuses',
#  272: 'accusing',
#  273: 'accustomed',
#  274: 'accutane',
#  275: 'ace',
#  276: 'aced',
#  277: 'acensoreding',
#  278: 'acensoredingmen',
#  279: 'achairscouches',
#  280: 'ache',
#  281: 'acheivmentpleasure',
#  282: 'aches',
#  283: 'achey',
#  284: 'achieve',
#  285: 'achieveafter',
#  286: 'achieved',
#  287: 'achievement',
#  288: 'achiever',
#  289: 'achievers',
#  290: 'achieving',
#  291: 'achilles',
#  292: 'aching',
#  293: 'achondroplastic',
#  294: 'acid',
#  295: 'acidic',
#  296: 'acidmushrooms',
#  297: 'ackbar',
#  298: 'acknowledge',
#  299: 'acknowledged',
#  300: 'acknowledgedi',
#  301: 'acknowledgement',
#  302: 'acknowledges',
#  303: 'acknowledging',
#  304: 'acknowledgment',
#  305: 'acls',
#  306: 'aclu',
#  307: 'aclui',
#  308: 'acne',
#  309: 'acoma',
#  310: 'acon',
#  311: 'acons',
#  312: 'acording',
#  313: 'acoustic',
#  314: 'acquaintance',
#  315: 'acquaintances',
#  316: 'acquainted',
#  317: 'acquiesce',
#  318: 'acquire',
#  319: 'acquired',
#  320: 'acquiring',
#  321: 'acquisition',
#  322: 'acres',
#  323: 'acrid',
#  324: 'acrimonious',
#  325: 'acrobat',
#  326: 'acrobats',
#  327: 'acronym',
#  328: 'acronyms',
#  329: 'across',
#  330: 'acrossand',
#  331: 'act',
#  332: 'acted',
#  333: 'acti',
#  334: 'actin',
#  335: 'acting',
#  336: 'actingits',
#  337: 'actingscreenwriting',
#  338: 'action',
#  339: 'actiondo',
#  340: 'actioned',
#  341: 'actionhero',
#  342: 'actions',
#  343: 'actionsbut',
#  344: 'actionsi',
#  345: 'actionsin',
#  346: 'actionsinaction',
#  347: 'actionsnext',
#  348: 'actionsthe',
#  349: 'actionwhat',
#  350: 'activate',
#  351: 'activated',
#  352: 'activatedgt',
#  353: 'activates',
#  354: 'activating',
#  355: 'activation',
#  356: 'active',
#  357: 'actively',
#  358: 'activisions',
#  359: 'activism',
#  360: 'activist',
#  361: 'activists',
#  362: 'activities',
#  363: 'activitiesbut',
#  364: 'activitiesgpastandardized',
#  365: 'activity',
#  366: 'activityanyway',
#  367: 'activityby',
#  368: 'activityi',
#  369: 'activityive',
#  370: 'activitythats',
#  371: 'actmany',
#  372: 'actor',
#  373: 'actorrip',
#  374: 'actors',
#  375: 'actorsactresses',
#  376: 'actress',
#  377: 'actresses',
#  378: 'acts',
#  379: 'actsestablished',
#  380: 'actslabel',
#  381: 'actthat',
#  382: 'actual',
#  383: 'actuality',
#  384: 'actually',
#  385: 'actuallymy',
#  386: 'actuallyohyeah',
#  387: 'actuallythere',
#  388: 'actwe',
#  389: 'acuras',
#  390: 'acurazine',
#  391: 'acus',
#  392: 'acute',
#  393: 'acutely',
#  394: 'acv',
#  395: 'ad',
#  396: 'adam',
#  397: 'adamant',
#  398: 'adams',
#  399: 'adapt',
#  400: 'adaptability',
#  401: 'adaptation',
#  402: 'adapted',
#  403: 'adapter',
#  404: 'adapters',
#  405: 'adapting',
#  406: 'adaptive',
#  407: 'adapts',
#  408: 'add',
#  409: 'addadhdits',
#  410: 'added',
#  411: 'adderall',
#  412: 'adderallamptrade',
#  413: 'addict',
#  414: 'addicted',
#  415: 'addictedyou',
#  416: 'addictinggamescom',
#  417: 'addiction',
#  418: 'addictions',
#  419: 'addictive',
#  420: 'addicts',
#  421: 'addictthe',
#  422: 'addied',
#  423: 'adding',
#  424: 'addition',
#  425: 'additional',
#  426: 'additionally',
#  427: 'additionallythen',
#  428: 'additionif',
#  429: 'additions',
#  430: 'addled',
#  431: 'addons',
#  432: 'address',
#  433: 'addressed',
#  434: 'addresses',
#  435: 'addressesthe',
#  436: 'addressing',
#  437: 'adds',
#  438: 'addy',
#  439: 'adept',
#  440: 'adequate',
#  441: 'adequately',
#  442: 'adequatelynote',
#  443: 'adhd',
#  444: 'adhdsorry',
#  445: 'adheres',
#  446: 'adhesionsskin',
#  447: 'adhesive',
#  448: 'aditya',
#  449: 'adjacent',
#  450: 'adjective',
#  451: 'adjectives',
#  452: 'adjudicate',
#  453: 'adjust',
#  454: 'adjustable',
#  455: 'adjusted',
#  456: 'adjusting',
#  457: 'adjustments',
#  458: 'adjusts',
#  459: 'admin',
#  460: 'administer',
#  461: 'administered',
#  462: 'administrated',
#  463: 'administration',
#  464: 'administrationoh',
#  465: 'administrative',
#  466: 'administrator',
#  467: 'administrators',
#  468: 'admins',
#  469: 'admirable',
#  470: 'admirably',
#  471: 'admiral',
#  472: 'admiration',
#  473: 'admirationhere',
#  474: 'admire',
#  475: 'admired',
#  476: 'admirer',
#  477: 'admirers',
#  478: 'admiring',
#  479: 'admission',
#  480: 'admissions',
#  481: 'admit',
#  482: 'admited',
#  483: 'admits',
#  484: 'admittably',
#  485: 'admitted',
#  486: 'admittedly',
#  487: 'admitting',
#  488: 'admonish',
#  489: 'admonished',
#  490: 'admonishing',
#  491: 'admonition',
#  492: 'admonitions',
#  493: 'adobe',
#  494: 'adolescence',
#  495: 'adolescencethe',
#  496: 'adolescent',
#  497: 'adolescents',
#  498: 'adolf',
#  499: 'adolph',
#  500: 'adonis',
#  501: 'adooooolph',
#  502: 'adopt',
#  503: 'adopted',
#  504: 'adopting',
#  505: 'adoption',
#  506: 'adoptions',
#  507: 'adoptive',
#  508: 'adopts',
#  509: 'adorable',
#  510: 'adorably',
#  511: 'adore',
#  512: 'adored',
#  513: 'adores',
#  514: 'adoring',
#  515: 'adorning',
#  516: 'adothe',
#  517: 'adrenaline',
#  518: 'adrenalinefilled',
#  519: 'adrenalinesimon',
#  520: 'adrenalinesorry',
#  521: 'adrock',
#  522: 'ads',
#  523: 'adsupported',
#  524: 'adult',
#  525: 'adultalso',
#  526: 'adultfamily',
#  527: 'adulthood',
#  528: 'adultmy',
#  529: 'adults',
#  530: 'adultsoh',
#  531: 'adultyou',
#  532: 'advance',
#  533: 'advancecarterdathird',
#  534: 'advanced',
#  535: 'advancement',
#  536: 'advancements',
#  537: 'advances',
#  538: 'advantage',
#  539: 'advantageous',
#  540: 'advantages',
#  541: 'advent',
#  542: 'adventure',
#  543: 'adventurer',
#  544: 'adventurerstalking',
#  545: 'adventures',
#  546: 'adventurous',
#  547: 'adverb',
#  548: 'adverbs',
#  549: 'adversaries',
#  550: 'adversarys',
#  551: 'adverse',
#  552: 'advertise',
#  553: 'advertised',
#  554: 'advertisement',
#  555: 'advertisements',
#  556: 'advertisementsnever',
#  557: 'advertisementsnotice',
#  558: 'advertisers',
#  559: 'advertiserso',
#  560: 'advertises',
#  561: 'advertising',
#  562: 'advertisingwell',
#  563: 'adverts',
#  564: 'advice',
#  565: 'adviceameen',
#  566: 'adviceanimal',
#  567: 'adviceanimals',
#  568: 'adviceif',
#  569: 'adviceno',
#  570: 'advicepick',
#  571: 'adviceus',
#  572: 'advicewe',
#  573: 'advisable',
#  574: 'advise',
#  575: 'advised',
#  576: 'adviser',
#  577: 'advises',
#  578: 'advising',
#  579: 'advisor',
#  580: 'advocate',
#  581: 'advocated',
#  582: 'advocates',
#  583: 'advocating',
#  584: 'adware',
#  585: 'adz',
#  586: 'aeilish',
#  587: 'aeilishs',
#  588: 'aeons',
#  589: 'aeop',
#  590: 'aequi',
#  591: 'aerial',
#  592: 'aerobics',
#  593: 'aerogel',
#  594: 'aeronautical',
#  595: 'aeroplane',
#  596: 'aerosol',
#  597: 'aerospace',
#  598: 'aesop',
#  599: 'aesthetic',
#  600: 'aesthetically',
#  601: 'aestheticeither',
#  602: 'aesthetics',
#  603: 'aetna',
#  604: 'af',
#  605: 'afaik',
#  606: 'afar',
#  607: 'aferwords',
#  608: 'aff',
#  609: 'affable',
#  610: 'affair',
#  611: 'affairi',
#  612: 'affairone',
#  613: 'affairs',
#  614: 'affairsgtth',
#  615: 'affect',
#  616: 'affected',
#  617: 'affecting',
#  618: 'affection',
#  619: 'affectionate',
#  620: 'affects',
#  621: 'affectual',
#  622: 'affidavit',
#  623: 'affiliate',
#  624: 'affiliated',
#  625: 'affirmation',
#  626: 'affirmative',
#  627: 'affirmed',
#  628: 'affirming',
#  629: 'affirms',
#  630: 'affleck',
#  631: 'afflicted',
#  632: 'afflictions',
#  633: 'affluent',
#  634: 'affluenza',
#  635: 'afford',
#  636: 'affordable',
#  637: 'afforded',
#  638: 'affordedit',
#  639: 'affording',
#  640: 'affront',
#  641: 'afghan',
#  642: 'afghanistan',
#  643: 'afk',
#  644: 'aflac',
#  645: 'aflame',
#  646: 'afoot',
#  647: 'afore',
#  648: 'aforementioned',
#  649: 'aforethought',
#  650: 'afraid',
#  651: 'afraidarthur',
#  652: 'afreshid',
#  653: 'africa',
#  654: 'africacensored',
#  655: 'africacpp',
#  656: 'african',
#  657: 'africanalien',
#  658: 'africanamericans',
#  659: 'africans',
#  660: 'africathis',
#  661: 'afro',
#  662: 'afroman',
#  663: 'afso',
#  664: 'aftemath',
#  665: 'after',
#  666: 'afterall',
#  667: 'afteram',
#  668: 'afteremily',
#  669: 'aftergthow',
#  670: 'afterhands',
#  671: 'afterhow',
#  672: 'afterlife',
#  673: 'afterlifeis',
#  674: 'aftermarket',
#  675: 'aftermath',
#  676: 'aftermathmy',
#  677: 'aftermy',
#  678: 'afternoon',
#  679: 'afternoonit',
#  680: 'afternoons',
#  681: 'afternow',
#  682: 'afterparty',
#  683: 'afterprom',
#  684: 'afterschool',
#  685: 'aftertaste',
#  686: 'afterthat',
#  687: 'afterthis',
#  688: 'afterward',
#  689: 'afterwards',
#  690: 'afterwardsgt',
#  691: 'afterwardsi',
#  692: 'afterwardsmy',
#  693: 'afterwardsthe',
#  694: 'afterwardsthis',
#  695: 'afterwardswow',
#  696: 'afterwhat',
#  697: 'afterwords',
#  698: 'ag',
#  699: 'aga',
#  700: 'again',
#  701: 'againafter',
#  702: 'againand',
#  703: 'againas',
#  704: 'againbrother',
#  705: 'againby',
#  706: 'againcounselling',
#  707: 'againdid',
#  708: 'againdifficulty',
#  709: 'againdo',
#  710: 'againdont',
#  711: 'againdt',
#  712: 'againedit',
#  713: 'againeditholy',
#  714: 'againfunny',
#  715: 'againgenerally',
#  716: 'againgetting',
#  717: 'againgod',
#  718: 'againgspot',
#  719: 'againgt',
#  720: 'againhere',
#  721: 'againheres',
#  722: 'againi',
#  723: 'againid',
#  724: 'againif',
#  725: 'againim',
#  726: 'againit',
#  727: 'againits',
#  728: 'againlesson',
#  729: 'againloving',
#  730: 'againmakes',
#  731: 'againmaybe',
#  732: 'againmy',
#  733: 'againnot',
#  734: 'againnow',
#  735: 'againoh',
#  736: 'againokay',
#  737: 'againoutbreak',
#  738: 'againput',
#  739: 'againrealistically',
#  740: 'againshe',
#  741: 'againso',
#  742: 'againsorry',
#  743: 'against',
#  744: 'againsteves',
#  745: 'againstrezeas',
#  746: 'againsure',
#  747: 'againtext',
#  748: 'againthe',
#  749: 'againthen',
#  750: 'againtheres',
#  751: 'againthis',
#  752: 'againtldr',
#  753: 'againtotally',
#  754: 'againtyler',
#  755: 'againuh',
#  756: 'againwait',
#  757: 'againwe',
#  758: 'againwhat',
#  759: 'againwhen',
#  760: 'againwith',
#  761: 'againyes',
#  762: 'againyou',
#  763: 'againyour',
#  764: 'againyoure',
#  765: 'agape',
#  766: 'agassi',
#  767: 'age',
#  768: 'ageand',
#  769: 'ageappropriate',
#  770: 'agearthur',
#  771: 'aged',
#  772: 'agegt',
#  773: 'agegti',
#  774: 'agehe',
#  775: 'ageimagine',
#  776: 'ageing',
#  777: 'ageit',
#  778: 'ageless',
#  779: 'agelets',
#  780: 'agemy',
#  781: 'agencies',
#  782: 'agency',
#  783: 'agencytry',
#  784: 'agenda',
#  785: 'agent',
#  786: 'agents',
#  787: 'ages',
#  788: 'agesduring',
#  789: 'agesgtim',
#  790: 'ageshush',
#  791: 'ageso',
#  792: 'agggh',
#  793: 'aggies',
#  794: 'aggrandizing',
#  795: 'aggravate',
#  796: 'aggravation',
#  797: 'aggression',
#  798: 'aggressive',
#  799: 'aggressiveits',
#  800: 'aggressively',
#  801: 'aggressivemore',
#  802: 'aggressiveso',
#  803: 'aggressor',
#  804: 'aggressors',
#  805: 'aggrieved',
#  806: 'aggrivated',
#  807: 'aggro',
#  808: 'aghast',
#  809: 'agile',
#  810: 'agility',
#  811: 'aging',
#  812: 'agitated',
#  813: 'agnostic',
#  814: 'ago',
#  815: 'agoacknowledge',
#  816: 'agoand',
#  817: 'agobbcworld',
#  818: 'agobecause',
#  819: 'agobut',
#  820: 'agocant',
#  821: 'agocasual',
#  822: 'agoedit',
#  823: 'agogti',
#  824: 'agoheres',
#  825: 'agoi',
#  826: 'agoin',
#  827: 'agoits',
#  828: 'agolong',
#  829: 'agomans',
#  830: 'agonized',
#  831: 'agonizing',
#  832: 'agonizingly',
#  833: 'agony',
#  834: 'agonyguys',
#  835: 'agooh',
#  836: 'agoseriously',
#  837: 'agoshes',
#  838: 'agoshit',
#  839: 'agoso',
#  840: 'agosource',
#  841: 'agothere',
#  842: 'agrabahreapedage',
#  843: 'agree',
#  844: 'agreeable',
#  845: 'agreeadmit',
#  846: 'agreed',
#  847: 'agreeing',
#  848: 'agreement',
#  849: 'agreements',
#  850: 'agreementwell',
#  851: 'agreeok',
#  852: 'agrees',
#  853: 'agreethis',
#  854: 'agricultural',
#  855: 'agriculture',
#  856: 'agriculturegt',
#  857: 'agriculturemale',
#  858: 'agronar',
#  859: 'agronomic',
#  860: 'ags',
#  861: 'ah',
#  862: 'ahab',
#  863: 'ahahaha',
#  864: 'ahboohoo',
#  865: 'ahead',
#  866: 'aheadtldr',
#  867: 'ahem',
#  868: 'ahh',
#  869: 'ahhh',
#  870: 'ahhhh',
#  871: 'ahi',
#  872: 'ahmed',
#  873: 'ahmedyeah',
#  874: 'ahmyou',
#  875: 'ahold',
#  876: 'ahole',
#  877: 'aholeabout',
#  878: 'aholealso',
#  879: 'aholecute',
#  880: 'aholeevery',
#  881: 'aholeftfybeing',
#  882: 'aholegt',
#  883: 'aholei',
#  884: 'aholeim',
#  885: 'aholeit',
#  886: 'aholeive',
#  887: 'aholemaybe',
#  888: 'aholemeh',
#  889: 'aholeness',
#  890: 'aholery',
#  891: 'aholethese',
#  892: 'aholewomen',
#  893: 'aholeyou',
#  894: 'ahoy',
#  895: 'ahs',
#  896: 'ahthis',
#  897: 'ahve',
#  898: 'ai',
#  899: 'aid',
#  900: 'aide',
#  901: 'aiden',
#  902: 'aides',
#  903: 'aidits',
#  904: 'aids',
#  905: 'aiguillettes',
#  906: 'aiko',
#  907: 'aim',
#  908: 'aimed',
#  909: 'aiming',
#  910: 'aims',
#  911: 'aimwhat',
#  912: 'aint',
#  913: 'air',
#  914: 'airanyone',
#  915: 'airbender',
#  916: 'airborn',
#  917: 'airborne',
#  918: 'airbrush',
#  919: 'aircard',
#  920: 'aircraft',
#  921: 'airdennis',
#  922: 'aired',
#  923: 'airfield',
#  924: 'airfields',
#  925: 'airhowever',
#  926: 'airing',
#  927: 'airings',
#  928: 'airline',
#  929: 'airlines',
#  930: 'airplane',
#  931: 'airplanesjust',
#  932: 'airplay',
#  933: 'airport',
#  934: 'airportbring',
#  935: 'airports',
#  936: 'airs',
#  937: 'airspace',
#  938: 'airstrikes',
#  939: 'airwalk',
#  940: 'airway',
#  941: 'airwaysyou',
#  942: 'airyfairy',
#  943: 'aisle',
#  944: 'aisledespite',
#  945: 'aisles',
#  946: 'ait',
#  947: 'aitkin',
#  948: 'ajar',
#  949: 'ak',
#  950: 'aka',
#  951: 'akafrank',
#  952: 'akbar',
#  953: 'ake',
#  954: 'akimbo',
#  955: 'akin',
#  956: 'akira',
#  957: 'akkadian',
#  958: 'aknc',
#  959: 'aku',
#  960: 'al',
#  961: 'ala',
#  962: 'alabama',
#  963: 'aladdin',
#  964: 'alamo',
#  965: 'alan',
#  966: 'alanis',
#  967: 'alarm',
#  968: 'alarmed',
#  969: 'alarming',
#  970: 'alarmingly',
#  971: 'alarmist',
#  972: 'alarms',
#  973: 'alas',
#  974: 'alaska',
#  975: 'alaskan',
#  976: 'alays',
#  977: 'albania',
#  978: 'albany',
#  979: 'albatross',
#  980: 'albeit',
#  981: 'albert',
#  982: 'albertan',
#  983: 'alberteinsteinit',
#  984: 'alberts',
#  985: 'albino',
#  986: 'albrecht',
#  987: 'albright',
#  988: 'album',
#  989: 'albuma',
#  990: 'albumchief',
#  991: 'albumdetox',
#  992: 'albumin',
#  993: 'albumnoname',
#  994: 'albums',
#  995: 'albumtde',
#  996: 'albumwhat',
#  997: 'alchemist',
#  998: 'alchemists',
#  999: 'alchol',
#  1000: 'alcohol',
#  ...}

# %%
# Train - Test Split #randomized
X, y = txt.comment, txt.reply
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1)

#x_train = comment , y_train = reply

# %%
#Save the train and test dataframes for reproducing the results later, as they are shuffled.
X_train.to_pickle('X_train.pkl')
X_test.to_pickle('X_test.pkl')

# %%
#batch_size = number of examples pulled at once for the model
def generate_batch(X = X_train, y = y_train, batch_size = 1000):
    ''' Generate a batch of data '''
    while True:
        #0=min, len(X)= max, batch_size=the step inbetween values
        for j in range(0, len(X), batch_size):
            #matrix of zeros 128*47
            encoder_source_data = np.zeros((batch_size, max_length_src),dtype='float32')
            #matrix of zeros 128*38
            decoder_source_data = np.zeros((batch_size, max_length_tar),dtype='float32')
            #matrix of zeros 128*38*28427
            decoder_target_data = np.zeros((batch_size, max_length_tar, num_decoder_tokens),dtype='float32')
            
            #iterates over source_text and target_text together
            #zips(iterates through) (current batch from X, and the current batch from y)
            for i, (source_text, target_text) in enumerate(zip(X[j:j+batch_size], y[j:j+batch_size])):
                #Enumerate() method adds a counter to an iterable and returns it in a form of enumerate object.
                #iterates over t? value and word in the in the comments AKA source_text
                for t, word in enumerate(source_text.split()):
                    #added to encoder
                    encoder_source_data[i, t] = source_token_index[word] # encoder input seq
                    
                for t, word in enumerate(target_text.split()):
                    if t<len(target_text.split())-1:
                        decoder_source_data[i, t] = target_token_index[word] # decoder input seq
                    if t>0:
                        # decoder target sequence (one hot encoded)
                        # does not include the START_ token
                        # Offset by one timestep
                        decoder_target_data[i, t - 1, target_token_index[word]] = 1.
            yield([encoder_source_data, decoder_source_data], decoder_target_data)

# %%
#Encoder Decoder Model Architure
#variables are variables which we do not directly observe, but which we assume to exist 

latent_dim = 50

# %%
#Encoder
encoder_inputs = Input(shape=(None,))
enc_emb =  Embedding(num_encoder_tokens, latent_dim, mask_zero = True)(encoder_inputs)
encoder_lstm = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder_lstm(enc_emb)
# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# %%
# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None,))
dec_emb_layer = Embedding(num_decoder_tokens, latent_dim, mask_zero = True)
dec_emb = dec_emb_layer(decoder_inputs)
# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(dec_emb,
                                     initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['acc'])

# %%
train_samples = len(X_train)
val_samples = len(X_test)
batch_size = 100
epochs = 50

train_samples, val_samples
# Out:
# (10856, 1207)

# %%
model.fit_generator(generator = generate_batch(X_train, y_train, batch_size = batch_size),
                    steps_per_epoch = train_samples//batch_size,
                    epochs=epochs,
                    validation_data = generate_batch(X_test, y_test, batch_size = batch_size),
                    validation_steps = val_samples//batch_size)
# Out:
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/50

# %%
model.save_weights('nmt_weights.h5')
model.load_weights('nmt_weights.h5')

# %%
#INFERENCE SET UP
# Encode the input sequence to get the "thought vectors"
encoder_model = Model(encoder_inputs, encoder_states)

# Decoder setup
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

dec_emb2= dec_emb_layer(decoder_inputs) # Get the embeddings of the decoder sequence

# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=decoder_states_inputs)
decoder_states2 = [state_h2, state_c2]
decoder_outputs2 = decoder_dense(decoder_outputs2) # A dense softmax layer to generate prob dist. over the target vocabulary

# Final decoder model
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs2] + decoder_states2)

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0] = target_token_index['START_']

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += ' '+sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_char == '_END' or
           len(decoded_sentence) > 50):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update states
        states_value = [h, c]

    return decoded_sentence

# %%
train_gen = generate_batch(X_train, y_train, batch_size = 1)
k=-1

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input:', X_train[k:k+1].values[0])
print('Actual reply:', y_train[k:k+1].values[0][6:-4])
print('Predicted reply:', decoded_sentence[:-4])

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input:', X_train[k:k+1].values[0])
print('Actual:', y_train[k:k+1].values[0][6:-4])
print('Predicted:', decoded_sentence[:-4])

# %%
#How to take user input??
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)

print('Input English sentence:', 'My name is Paulina')
print('Actual:', 'Thats cool! My name is Todd')
print('Predicted:', decoded_sentence[:-4])
